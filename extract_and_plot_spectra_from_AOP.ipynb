# %% [markdown]
# ### code to extract and plot spectra from a single NEON AOP pixel
# Yi Qi
# July 10, 2018
# yqi7@unl.edu
#
# The goal is to extract a single pixel from a hyperspectral hdf5 file and plot 3 figures, both without removing the bad bands of unusable data and with those bands. We also want to export a csv of the cleaned wavelength and reflectance info for use later.

# %%
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from copy import copy
import IPython
# %matplotlib inline

# %%
refl_filename = ('../data/NEON_D17_SJER_DP1_20180401_184649_reflectance.h5')
refl_filename
# Out:
# '../data/NEON_D17_SJER_DP1_20180401_184649_reflectance.h5'

# %%
pixel_to_plot=(100,100)
pixel_to_plot
# Out:
# (100, 100)

# %%
# read in reflectance hdf5 file
hdf5_file = h5py.File(refl_filename,'r')
hdf5_file
# Out:
# <HDF5 file "NEON_D17_SJER_DP1_20180401_184649_reflectance.h5" (mode r)>

# %%
hdf5_file.items()
# Out:
# ItemsViewHDF5(<HDF5 file "NEON_D17_SJER_DP1_20180401_184649_reflectance.h5" (mode r)>)

# %%
list(hdf5_file.items())
# Out:
# [('SJER', <HDF5 group "/SJER" (1 members)>)]

# %%
str(list(hdf5_file.items()))
# Out:
# '[(\'SJER\', <HDF5 group "/SJER" (1 members)>)]'

# %%
# get the file name
file_attrs_string = str(list(hdf5_file.items()))
file_attrs_string
# Out:
# '[(\'SJER\', <HDF5 group "/SJER" (1 members)>)]'

# %%
file_attrs_string_split = file_attrs_string.split("'")
file_attrs_string_split
# Out:
# ['[(', 'SJER', ', <HDF5 group "/SJER" (1 members)>)]']

# %%
sitename = file_attrs_string_split[1]
sitename
# Out:
# 'SJER'

# %%
refl = hdf5_file[sitename]['Reflectance']
refl
# Out:
# <HDF5 group "/SJER/Reflectance" (2 members)>

# %%
list(refl.attrs)
# Out:
# ['Description',
#  'Sensor',
#  'PayloadID',
#  'Scripts',
#  'Acquisition_Time',
#  'Band_Window_1_Nanometers',
#  'Band_Window_2_Nanometers']

# %%
# get the reflectance data
refldata = refl['Reflectance_Data']
refldata
# Out:
# <HDF5 dataset "Reflectance_Data": shape (216, 699, 426), type "<i2">

# %%
# get the raw values for the reflectance data
reflRaw = refldata.value
reflRaw
# Out:
# array([[[-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         ...,
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999]],
#
#        [[-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         ...,
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999]],
#
#        [[-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         ...,
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999]],
#
#        ...,
#
#        [[-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         ...,
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999]],
#
#        [[-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         ...,
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999]],
#
#        [[-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         ...,
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#         [-9999, -9999, -9999, ..., -9999, -9999, -9999]]], dtype=int16)

# %%
# create dictionary containing relevant metadata information
# make empty dictionary first
metadata = {}
metadata
# Out:
# {}

# %%
type(metadata)
# Out:
# dict

# %%
# store the map_info into a key of the same name
metadata['map_info'] = refl['Metadata']['Coordinate_System']['Map_Info'].value
metadata
# Out:
# {'map_info': b'UTM,  1.000,  1.000,  254192.000,  4102883.000,  1.0000000000e+000,  1.0000000000e+000,  11,  North,  WGS-84,  units=Meters, 0'}

# %%
metadata['wavelength'] = refl['Metadata']['Spectral_Data']['Wavelength'].value
metadata
# Out:
# {'map_info': b'UTM,  1.000,  1.000,  254192.000,  4102883.000,  1.0000000000e+000,  1.0000000000e+000,  11,  North,  WGS-84,  units=Meters, 0',
#  'wavelength': array([ 381.375793,  386.385986,  391.396301,  396.406586,  401.416901,
-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         ...,
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.]],
#
#        [[-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         ...,
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.]],
#
#        [[-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         ...,
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.]],
#
#        ...,
#
#        [[-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         ...,
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.]],
#
#        [[-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         ...,
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.]],
#
#        [[-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         ...,
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#         [-9999., -9999., -9999., ..., -9999., -9999., -9999.]]])

# %%
# capture shape of this raw data
arr_size = reflClean.shape
arr_size
# Out:
# (216, 699, 426)

# %%
number_of_values_where_no_data = np.count_nonzero(reflClean == metadata['data_ignore_value'])
number_of_values_where_no_data
# Out:
# 31535502

# %%
total_number_of_values_in_array = (arr_size[0] * arr_size[1] * arr_size[2])
total_number_of_values_in_array
# Out:
# 64319184

# %%
# check for the number of missing data points
# no result here means all clean
if metadata['data_ignore_value'] in reflRaw:
    # print out the percent with no dat rounded to 1 decimal place
    print('% of points with no data: ',
         np.round(number_of_values_where_no_data * 100 / total_number_of_values_in_array,1))
    
    # replace the ignore values NaNs
    nodata_ind = np.where(reflClean == metadata['data_ignore_value'])
    reflClean[nodata_ind] = np.nan
# Out:
# % of points with no data:  49.0

# %%
# apply scale factor
reflArray = reflClean / metadata['reflectance_scale_factor']
reflArray
# Out:
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        ...,
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]])

# %%
# extract spatial extent from attributes
metadata['spatial_extent'] = refldata.attrs['Spatial_Extent_meters']
metadata['spatial_extent']
# Out:
# array([ 254192.,  254891., 4102667., 4102883.])

# %%
# Extract bad band windows
metadata['bad band window1'] = (refl.attrs['Band_Window_1_Nanometers'])
metadata['bad band window1']
# Out:
# array([1340, 1445])

# %%
metadata['bad band window2'] = (refl.attrs['Band_Window_2_Nanometers'])
metadata['bad band window2']
# Out:
# array([1790, 1955])

# %%
# Extract projection information
# metadata['projection'] = refl['Metadata']['Coordinate_System']['Proj4'].value
metadata['epsg'] = int(refl['Metadata']['Coordinate_System']['EPSG Code'].value)
metadata['epsg']
# Out:
# 32611

# %%
# Extract map information: spatial extent & resolution (pixel size)
mapInfo = refl['Metadata']['Coordinate_System']['Map_Info'].value
mapInfo
# Out:
# b'UTM,  1.000,  1.000,  254192.000,  4102883.000,  1.0000000000e+000,  1.0000000000e+000,  11,  North,  WGS-84,  units=Meters, 0'

# %%
hdf5_file.close
# Out:
# <bound method File.close of <HDF5 file "NEON_D17_SJER_DP1_20180401_184649_reflectance.h5" (mode r)>>

# %%
# make a new empty pandas dataframe
serc_pixel_df = pd.DataFrame()

# %%
# add a column of reflectance data from the cleaned reflectance array
serc_pixel_df['reflectance'] = reflArray[pixel_to_plot[0],pixel_to_plot[1],:]

# %%
# add a second column to the data frame with the wavelength info
serc_pixel_df['wavelength'] = metadata['wavelength']

# %%
# check for any weirdness
serc_pixel_df.head(5)
# Out:
#    reflectance  wavelength
# 0       0.0233  381.375793
# 1       0.0326  386.385986
# 2       0.0337  391.396301
# 3       0.0359  396.406586
# 4       0.0347  401.416901

# %%
# check for tail weirdness
serc_pixel_df.tail(5)
# Out:
#      reflectance   wavelength
# 421       0.0918  2490.703125
# 422       0.1010  2495.713379
# 423       0.0983  2500.723633
# 424       0.0850  2505.733887
# 425       0.0836  2510.744141

# %%
# make a plot!!
serc_pixel_df.plot(x='wavelength',
                  y='reflectance',
                  kind='scatter',
                  edgecolor='none')
plt.title('Spectral Signature for '+sitename+ ' Pixel '+', '.join(map(str,pixel_to_plot)))

ax=plt.gca() # gca is short for get current axes

ax.set_xlim([np.min(serc_pixel_df['wavelength']),
            np.max(serc_pixel_df['wavelength'])])

ax.set_ylim(np.min(serc_pixel_df['reflectance']),
           np.max(serc_pixel_df['reflectance']))
ax.set_xlabel("Wavelength,nm")
ax.set_ylabel("Reflectance")
ax.grid(True)

fig = ax.get_figure()
fig.savefig('output/figs/'+sitename+'_plot1.png')

# %%
bbw1 = metadata['bad band window1']
print('Bad Band Window 1:', bbw1)
# Out:
# Bad Band Window 1: [1340 1445]

# %%
bbw2 = metadata['bad band window2']
print('Bad Band Window 2:', bbw2)
# Out:
# Bad Band Window 2: [1790 1955]

# %%
# make a plot with the bad regions plotted
serc_pixel_df.plot(x='wavelength',
                   y='reflectance',
                   kind='scatter',
                   edgecolor='none')

plt.title('Spectral Signature for '+sitename+' Pixel '+', '.join(map(str, pixel_to_plot)))

ax1 = plt.gca()
ax1.grid(True)

ax1.set_xlim([np.min(serc_pixel_df['wavelength']),
              np.max(serc_pixel_df['wavelength'])])

ax1.set_ylim(0,0.5)

ax1.set_xlabel("Wavelength, nm")
ax1.set_ylabel("Reflectance")

# Add in red dotted lines to show boundaries of bad band windows:
ax1.plot((bbw1[0], bbw1[0]), (0,1.5), 'r--')
ax1.plot((bbw1[1], bbw1[1]), (0,1.5), 'r--')
ax1.plot((bbw2[0], bbw2[0]), (0,1.5), 'r--')
ax1.plot((bbw2[1], bbw2[1]), (0,1.5), 'r--')

fig = ax1.get_figure()
fig.savefig('output/figs/'+sitename+'_plot2.png')

# %%
# make a copy to deal with the mutable data type
w = copy(metadata['wavelength'])

w[((w >= bbw1[0]) & (w <= bbw1[1])) | ((w >= bbw2[0]) & (w <= bbw2[1]))] = np.nan 

# the last 10 bands sometimes have noise - best to eliminate
w[-10:] = np.nan

# optionally print wavelength values to show that -9999 values are replaced with nan
w
# Out:
# array([ 381.375793,  386.385986,  391.396301,  396.406586,  401.416901,
#         406.427185,  411.437408,  416.447693,  421.458008,  426.468292,
#         431.478485,  436.4888  ,  441.499115,  446.509399,  451.519714,
#         456.529907,  461.540192,  466.550507,  471.560791,  476.571106,
#         481.581299,  486.591614,  491.601898,  496.612213,  501.622406,
#         506.63269 ,  511.643005,  516.65332 ,  521.663574,  526.673828,
#         531.684082,  536.694397,  541.704712,  546.715027,  551.72522 ,
#         556.735474,  561.745789,  566.756104,  571.766296,  576.776611,
#         581.786926,  586.79718 ,  591.807495,  596.817688,  601.828003,
#         606.838318,  611.848572,  616.858887,  621.86908 ,  626.879395,
#         631.889709,  636.900024,  641.910278,  646.920471,  651.930786,
#         656.941101,  661.951416,  666.961609,  671.971924,  676.982178,
#         681.992493,  687.002808,  692.013   ,  697.023315,  702.03363 ,
#         707.043884,  712.054199,  717.064392,  722.074707,  727.085022,
#         732.095276,  737.10553 ,  742.115784,  747.126099,  752.136414,
#         757.146729,  762.156921,  767.167175,  772.17749 ,  777.187805,
#        2160.024658, 2165.034912, 2170.04541 , 2175.055664, 2180.065918,
#        2185.076172, 2190.086426, 2195.09668 , 2200.106934, 2205.117188,
#        2210.127441, 2215.137695, 2220.148193, 2225.158203, 2230.168701,
#        2235.178955, 2240.189209, 2245.199463, 2250.209717, 2255.219971,
#        2260.230225, 2265.240479, 2270.250977, 2275.260986, 2280.271484,
#        2285.281738, 2290.291992, 2295.302246, 2300.3125  , 2305.322754,
#        2310.333008, 2315.343506, 2320.353516, 2325.364014, 2330.374268,
#        2335.384521, 2340.394775, 2345.405029, 2350.415283, 2355.425537,
#        2360.435791, 2365.446289, 2370.456299, 2375.466797, 2380.477051,
#        2385.487305, 2390.497559, 2395.507813, 2400.518066, 2405.52832 ,
#        2410.538818, 2415.548828, 2420.559082, 2425.56958 , 2430.579834,
#        2435.590088, 2440.600342, 2445.610596, 2450.62085 , 2455.631104,
#        2460.641357,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan])

# %%
serc_pixel_df['wavelength'] = w
serc_pixel_df
# Out:
#      reflectance   wavelength
# 0         0.0233   381.375793
# 1         0.0326   386.385986
# 2         0.0337   391.396301
# 3         0.0359   396.406586
# 4         0.0347   401.416901
# 5         0.0342   406.427185
# 6         0.0352   411.437408
# 7         0.0349   416.447693
# 8         0.0360   421.458008
# 9         0.0360   426.468292
# 10        0.0402   431.478485
# 11        0.0402   436.488800
# 12        0.0416   441.499115
# 13        0.0437   446.509399
# 14        0.0440   451.519714
# 15        0.0447   456.529907
# 16        0.0437   461.540192
# 17        0.0444   466.550507
# 18        0.0435   471.560791
# 19        0.0460   476.571106
# 20        0.0461   481.581299
# 21        0.0463   486.591614
# 22        0.0467   491.601898
# 23        0.0473   496.612213
# 24        0.0474   501.622406
# 25        0.0488   506.632690
# 26        0.0505   511.643005
# 27        0.0502   516.653320
# 28        0.0498   521.663574
# 29        0.0510   526.673828
# ..           ...          ...
# 396       0.1256  2365.446289
# 397       0.1232  2370.456299
# 398       0.1237  2375.466797
# 399       0.1216  2380.477051
# 400       0.1205  2385.487305
# 401       0.1236  2390.497559
# 402       0.1237  2395.507813
# 403       0.1212  2400.518066
# 404       0.1189  2405.528320
# 405       0.1155  2410.538818
# 406       0.1160  2415.548828
# 407       0.1138  2420.559082
# 408       0.1142  2425.569580
# 409       0.1162  2430.579834
# 410       0.1118  2435.590088
# 411       0.1060  2440.600342
# 412       0.1025  2445.610596
# 413       0.1007  2450.620850
# 414       0.0982  2455.631104
# 415       0.1013  2460.641357
# 416       0.0979          NaN
# 417       0.0967          NaN
# 418       0.0909          NaN
# 419       0.0926          NaN
# 420       0.0923          NaN
# 421       0.0918          NaN
# 422       0.1010          NaN
# 423       0.0983          NaN
# 424       0.0850          NaN
# 425       0.0836          NaN
#
# [426 rows x 2 columns]

# %%
serc_pixel_df.to_csv('output/csv/'+sitename+'.csv')

# %%
serc_pixel_df.plot(x='wavelength',
                   y='reflectance',
                   kind='scatter',
                   edgecolor='none')

plt.title('Spectral Signature for '+sitename+' Pixel '+', '.join(map(str, pixel_to_plot)))

ax2 = plt.gca() # stands for 'get current axis'
ax2.grid(True)
ax2.set_xlim([np.min(serc_pixel_df['wavelength']),
              np.max(serc_pixel_df['wavelength'])])
ax2.set_ylim(0,0.5)
ax2.set_xlabel("Wavelength, nm")
ax2.set_ylabel("Reflectance")

#Add in red dotted lines to show boundaries of bad band windows:
ax2.plot((1340,1340), (0,1.5), 'r--')
ax2.plot((1445,1445), (0,1.5), 'r--')
ax2.plot((1790,1790), (0,1.5), 'r--')
ax2.plot((1955,1955), (0,1.5), 'r--')

fig = ax2.get_figure()

fig.savefig('output/figs/'+sitename+'_plot3.png')

# %%
# %whos
# Out:
# Variable                          Type           Data/Info
# ----------------------------------------------------------
# IPython                           module         <module 'IPython' from 'C<...>s\\IPython\\__init__.py'>
# arr_size                          tuple          n=3
# ax                                AxesSubplot    AxesSubplot(0.125,0.125;0.775x0.755)
# ax1                               AxesSubplot    AxesSubplot(0.125,0.125;0.775x0.755)
# ax2                               AxesSubplot    AxesSubplot(0.125,0.125;0.775x0.755)
# bbw1                              ndarray        2: 2 elems, type `int32`, 8 bytes
# bbw2                              ndarray        2: 2 elems, type `int32`, 8 bytes
# copy                              function       <function copy at 0x000002553AC7C0D0>
# fig                               Figure         Figure(432x288)
# file_attrs_string                 str            [('SJER', <HDF5 group "/SJER" (1 members)>)]
# file_attrs_string_split           list           n=3
# h5py                              module         <module 'h5py' from 'C:\\<...>ages\\h5py\\__init__.py'>
# hdf5_file                         File           <HDF5 file "NEON_D17_SJER<...>reflectance.h5" (mode r)>
# mapInfo                           bytes          b'UTM,  1.000,  1.000,  2<...>WGS-84,  units=Meters, 0'
# metadata                          dict           n=8
# nodata_ind                        tuple          n=3
# np                                module         <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# number_of_values_where_no_data    int            31535502
# pd                                module         <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# pixel_to_plot                     tuple          n=2
# plt                               module         <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# refl                              Group          <HDF5 group "/SJER/Reflectance" (2 members)>
# reflArray                         ndarray        216x699x426: 64319184 elems, type `float64`, 514553472 bytes (490.7164306640625 Mb)
# reflClean                         ndarray        216x699x426: 64319184 elems, type `float64`, 514553472 bytes (490.7164306640625 Mb)
# reflRaw                           ndarray        216x699x426: 64319184 elems, type `int16`, 128638368 bytes (122.67910766601562 Mb)
# refl_filename                     str            ../data/NEON_D17_SJER_DP1<...>401_184649_reflectance.h5
# refldata                          Dataset        <HDF5 dataset "Reflectanc<...>6, 699, 426), type "<i2">
# serc_pixel_df                     DataFrame           reflectance   wavele<...>n\n[426 rows x 2 columns]
# sitename                          str            SJER
# total_number_of_values_in_array   int            64319184
# w                                 ndarray        426: 426 elems, type `float64`, 3408 bytes

# %%
print(IPython.sys_info())
# Out:
# {'commit_hash': '7f10f7bb3',
#  'commit_source': 'installation',
#  'default_encoding': '1252',
#  'ipython_path': 'C:\\Users\\qiyib\\AppData\\Local\\conda\\conda\\envs\\p35\\lib\\site-packages\\IPython',
#  'ipython_version': '6.4.0',
#  'os_name': 'nt',
#  'platform': 'Windows-10-10.0.16299-SP0',
#  'sys_executable': 'C:\\Users\\qiyib\\AppData\\Local\\conda\\conda\\envs\\p35\\python.exe',
#  'sys_platform': 'win32',
#  'sys_version': '3.5.5 |Anaconda custom (64-bit)| (default, Apr  7 2018, '
#                 '04:52:34) [MSC v.1900 64 bit (AMD64)]'}
